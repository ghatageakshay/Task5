# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          Date     Month Product  Sales
# 0  2025-01-01   January  Mobile  12000
# 1  2025-01-02   January  Laptop  18000
# 2  2025-01-03   January  Tablet   9000
# 3  2025-02-01  February  Mobile  15000
# 4  2025-02-02  February  Laptop  22000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     9 non-null      object
#  1   Month    9 non-null      object
#  2   Product  9 non-null      object
#  3   Sales    9 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 420.0+ bytes

# %%
df.describe()
# Out:
#               Sales
# count      9.000000
# mean   15222.222222
# std     5911.382617
# min     7000.000000
# 25%    12000.000000
# 50%    15000.000000
# 75%    18000.000000
# max    25000.000000

# %%
sales_by_product=df.groupby("Product")["Sales"].sum()
sales_by_product
# Out:
# Product
# Laptop    65000
# Mobile    44000
# Tablet    28000
# Name: Sales, dtype: int64

# %%
sales_by_month=df.groupby("Month")["Sales"].sum()
sales_by_month
# Out:
# Month
# February    44000
# January     39000
# March       54000
# Name: Sales, dtype: int64

# %%
sales_by_product.plot(kind="bar")
plt.title("Total Sales by product")
plt.ylabel("Sales")
plt.show()

# %%
sales_by_month.plot(kind="line",marker='o')
plt.title("Sales Trend By Month")
plt.ylabel("Sales")
plt.show()
